# %%
def write(json_data: dict, file_name: str):
    with open(file_name, 'w') as f:
        f.write(json.dumps(json_data))

space = '         '
req_interval = 1.25
req_interval_long = 60 * 5

# %%
# Download list of all currencies
import urllib
import json
import time

url = 'https://api.coingecko.com/api/v3/coins/list?include_platform=true'
response = urllib.request.urlopen(url)
currencies = json.loads(response.read())
write(currencies, 'tmp_step_01.json')
print('Downloaded list of ', len(currencies))
time.sleep(req_interval)
# Out:
# Downloaded list of  12968

# %%
# Include only native or ethereum ERC20s

def include(currency: dict) -> bool:
    if len(currency['platforms']) == 0:
        return True
    if 'ethereum' in currency['platforms']:
        return len(currency['platforms']['ethereum']) != 0
    return False

currencies = list(filter(lambda c: include(c) , currencies))

# Change id to coinGeckoId
for currency in currencies:
    currency['coinGeckoId'] = currency['id']
    currency.pop('id', None )

write(currencies, 'tmp_step_02.json')
print('Filtered out unsupported, remaining count', len(currencies))
# Out:
# Filtered out unsupported, remaining count 6311

# %%
# Get image url rank description
import time
import numpy as np
import requests

base_url = 'https://api.coingecko.com/api/v3/coins/'
query_params = '?localization=false&tickers=false&market_data=false&community_data=false&developer_data=false&sparkline=false'

for idx, currency in enumerate(currencies):
    url = base_url + currency['coinGeckoId'] + query_params
    info = dict()
    try:
        response = urllib.request.urlopen(url)
        info = json.loads(response.read())
    except:
        print('\r', 'Sleeping for 61s', idx, space, end='')
        time.sleep(req_interval_long)
        response = urllib.request.urlopen(url)
        info = json.loads(response.read())

    if 'image' in info and 'large' in info['image']:
        currency['imageUrl'] = info['image']['large']

    if 'coingecko_rank' in info:
        currency['rank'] = info['coingecko_rank']

    if 'links' in info:
        if 'homepage' in info['links'] and len(info['links']['homepage']) != 0:
            currency['link'] = info['links']['homepage'][0]

        if 'twitter_screen_name' in info['links'] is not None:
            currency['twitter'] = info['links']['twitter_screen_name']

    if 'description' in info and len(info['description']['en']) != 0:
        currency['description'] = info['description']['en']

    write(currencies, 'tmp_step_03.json')
    print('\r', 'Downloaded metadata', idx, end='')
    time.sleep(req_interval)
# Out:
#  Downloaded metadata 111

# %%
# Download images if needed
from urllib.parse import urljoin, urlparse
import os
import platform
import requests
import shutil

headers = requests.utils.default_headers()
default_agent = headers['User-Agent']
headers.update({'User-Agent': default_agent + ' (' + platform.platform() + ')'})
failed = list()

def file_name_for_url(url: str) -> str:
    return urljoin(url, urlparse(url).path).rsplit('/', 1)[-1]

def file_extension_for_url(url: str) -> str:
    return os.path.splitext(file_name_for_url(url))[-1]

def cache_image_file_name(id: str, url: str) -> str:
    return id + file_extension_for_url(url)

def download_image(currency: dict) -> int:
    image_name = cache_image_file_name(currency['coinGeckoId'], currency['imageUrl'])
    image_path = 'images/' + image_name
    if os.path.exists(image_path) == True or currency['imageUrl'] is None:
        return 200
    else:
        time.sleep(req_interval)
        res = requests.get(url, headers = headers, stream = True)
        if res.status_code == 200:
            with open(image_path, 'wb') as f:
                shutil.copyfileobj(res.raw, f)
                print('\r', 'Downloaded image', image_name, idx, space, end='')
        return res.status_code

for idx, currency in enumerate(currencies):
    status_code = download_image(currency)
    if status_code == 429:
        print('\r', 'Sleeping', currency['coinGeckoId'], idx, space, end='')
        time.sleep(req_interval_long)

print('Failed count', len(failed))

# %%
# Download market data

# %%
# Resize images
from PIL import Image
import os

image_length = 32 * 3
count = os.listdir('images/')

for idx, image_name in enumerate(os.listdir('images/')):
    path = 'images/' + image_name
    try:
        image = Image.open(path)
        if image.size[0] != image_length or image.size[1] != image_length:
            image.resize((image_length, image_length), reducing_gap=3.0)
            image.save(path)
        print('\r', 'Resizing image', image_name, idx, '/', count, space, end='')
    except:
        os.remove(path)
        print('removing', path)
# Out:
# removing images/bunnyverse.png
# removing images/nft-tech.png
# removing images/enterdao.png
# removing images/lunr-token.png
# removing images/arcblock.png
# removing images/gains.png
# removing images/cia.png
# removing images/hxro.png
# removing images/compound-governance-token.png
# removing images/bitcherry.png
# removing images/dbx-2.png
# removing images/mindcell.png
# removing images/myth-token.png
# removing images/erica-social-token.png
# removing images/nftlootbox.jpg
# removing images/multi-chain-capital-2.png
# removing images/tellor.png
# removing images/meschain.jpg
# removing images/nation3.png
# removing images/cherry-token.png
# removing images/moon-rabbit.png
# removing images/popcorn.png
# removing images/swftcoin.jpg
# removing images/hitchain.png
# removing images/lp-3pool-curve.png
# removing images/scry-info.jpg
# removing images/uranus.jpg
# removing images/blocks.png
# removing images/lyfe-silver.png
# removing images/clearpool.png
# removing images/dowcoin.png
# removing images/bittoken.png
# removing images/crypto-bank.jpg
# removing images/material.png
# removing images/midas-protocol.png
# removing images/celsius-degree-token.png
# removing images/stacktical.png
# removing images/aerotoken.jpg
# removing images/duckdaodime.png
# removing images/signata.png
# removing images/bondly.png
# removing images/quiverx.png
# removing images/bitonyx-token.png
# removing images/ooki.png
# removing images/neuromorphic-io.png
# removing images/lords.png
# removing images/tokamak-network.png
# removing images/1x-short-theta-network-token.png
# removing images/you-chain.jpg
# removing images/kori-inu.png
# removing images/chain-games.png
# removing images/dogsofelon.png
# removing images/media-licensing-token.png
# removing images/caspian.png
# removing images/education-assessment-cult.png
# removing images/polkadex.jpg
# removing images/polychain-monsters.png
# removing images/celsiusx-wrapped-doge.png
# removing images/aladdin-dao.png
# removing images/ecofi.png
# removing images/promotionchain.jpg
# removing images/cage.png
# removing images/goldex-token.png
# removing images/freeway.png
# removing images/marcopolo.png
# removing images/jarvis-reward-token.png
# removing images/bright-token.png
# removing images/orion-protocol.png
# removing images/rocket-pool.png
# removing images/green-light.png
# removing images/mobifi.png
# removing images/deepcloud-ai.png
# removing images/autonio.png
# removing images/dtravel.jpeg
# removing images/ethplus.png
# removing images/ethersmart.png
# removing images/snetwork.png
# removing images/metaverse-nft-index.png
# removing images/launchpool.jpg
# removing images/interest-bearing-bitcoin.png
# removing images/firmachain.jpg
# removing images/defi-yield-protocol.png
# removing images/bunnytoken.png
# removing images/dodo.png
# removing images/tokemak.png
# removing images/saito.png
# removing images/public-index-network.jpeg
# removing images/project-galaxy.png
# removing images/bidao.png
# removing images/elyfi.png
# removing images/coinwind.png
# removing images/enigma.png
# removing images/circuits-of-value.png
# removing images/debitum-network.jpg
# removing images/qash.jpeg
# removing images/terablock.png
# removing images/par-stablecoin.png
# removing images/agrello.png
# removing images/exrnchain.png
# removing images/gambler-shiba.jpg
# removing images/facts.jpg
# removing images/gameflip.png
# removing images/nurifootball.jpg
# removing images/phoenixdao.png
# removing images/gamb.png
# removing images/collective.png
# removing images/ucx.png
# removing images/robonomics-web-services.png
# removing images/spendcoin.png
# removing images/despace-protocol.jpg
# removing images/medibit.png
# removing images/linfinity.jpg
# removing images/blockburn.jpg
# removing images/aurigami.jpg
# removing images/litegold.jpg
# removing images/cxrbn-token.jpg
# removing images/oraichain-token.png
# removing images/calicoin.png
# removing images/crypto-com-chain.jpeg
# removing images/genesis-pool.png
# removing images/ampleforth.png
# removing images/kranz-token.png
# removing images/equos-origin.png
# removing images/charg-coin.png
# removing images/happy-birthday-coin.png
# removing images/flixxo.png
# removing images/opendao.jpg
# removing images/xmon.png
# removing images/tradestars.png
# removing images/true-usd.png
# removing images/fastswap.jpeg
# removing images/basis-coin-cash.jpg
# removing images/lition.png
# removing images/baby-floki-doge.png
# removing images/contribute.png
# removing images/azuma-coin.png
# removing images/nft-index.png
# removing images/cryptobonusmiles.png
# removing images/anchor-neural-world-token.png
# removing images/wild-credit.png
# removing images/thunder-token.png
# removing images/nami-corporation-token.png
# removing images/perlin.png
# removing images/the-red-order.png
# removing images/devery.png
# removing images/unslashed-finance.jpeg
# removing images/3x-long-vechain-token.png
# removing images/koi-network.jpeg
# removing images/olympus-v1.jpg
# removing images/tempus.png
# removing images/dixt-finance.png
# removing images/asia-coin.png
# removing images/polkafoundry.png
# removing images/zantepay.jpg
# removing images/mahadao.png
# removing images/umee.png
# removing images/tonstarter.png
# removing images/cortexdao.jpg
# removing images/latamcash.jpg
# removing images/jungle-token.jpg
# removing images/unipower.png
# removing images/barter.png
# removing images/chemix-ecology-governance-token.png
# removing images/metaverseair.jpg
# removing images/farmland-protocol.jpg
# removing images/whale.png
# removing images/faith-tribe.jpg
# removing images/strike.jpg
# removing images/quark-chain.png
# removing images/brmv-token.png
# removing images/chihua-token.png
# removing images/surf-finance.png
# removing images/life-crypto.png
# removing images/suncontract.png
# removing images/nftlaunch.png
# removing images/thales.png
# removing images/x-consoles.jpg
# removing images/naos-usd.png
# removing images/mnmcoin.png
# removing images/xtcom-token.jpg
# removing images/chopper-inu.png
# removing images/lobby.png
# removing images/miraqle.jpg
# removing images/golden-ratio-coin.png
# removing images/beyond-finance.png
# removing images/coinviewcap.png
# removing images/coldstack.png
# removing images/synapse-network.png
# removing images/bankless-dao.png
# removing images/triall.png
# removing images/locgame.png
# removing images/perpetual-protocol.png
# removing images/afin-coin.png
# removing images/ethverse.png
# removing images/glox-finance.png
# removing images/blackpearl-chain.png
# removing images/multiplanetary-inus.png
# removing images/m2.png
# removing images/refi.png
# removing images/wrapped-star.png
# removing images/no-one.png
# removing images/cappasity.png
# removing images/fortuna.png
# removing images/anyswap.jpg
# removing images/cnns.png
# removing images/veraone.png
# removing images/pepedex.png
# removing images/yearn-finance.png
# removing images/raze-network.png
# removing images/joystick-games.png
# removing images/torchain.jpg
# removing images/cropbytes.png
# removing images/lepricon.png
# removing images/kind-ads-token.png
# removing images/saud.png
# removing images/stakeborg-dao.jpg
# removing images/waifu-token.png
# removing images/compound-maker.png
# removing images/collateral-pay.jpg
# removing images/sf-capital.jpg
# removing images/hedget.png
# removing images/banque-universal.png
# removing images/boolean.png
# removing images/request-network.png
# removing images/genesis-shards.png
# removing images/dogdeficoin.jpg
# removing images/big-data-protocol.png
# removing images/ionchain-token.jpg
# removing images/vite.png
# removing images/unit-protocol-duck.png
# removing images/paxos-standard.png
# removing images/sentinel-group.png
# removing images/temco.jpg
# removing images/origin-sport.png
# removing images/bitnautic.jpg
# removing images/palletone.png
# removing images/cere-network.png
# removing images/medooza-ecosystem.png
# removing images/ecog9coin.png
# removing images/icarus-network.png
# removing images/xiotri.png
# removing images/blockpass.png
# removing images/piedao-defi-small-cap.png
# removing images/bomb.png
# removing images/musk-melon.png
# removing images/derace.png
# removing images/crdt.png
# removing images/spherium.png
# removing images/exponential-capital.png
# removing images/karma-dao.png
# removing images/mandala-exchange-token.png
# removing images/babb.png
# removing images/youminter.jpg
# removing images/tokenfy.png
# removing images/planet-inu.png
# removing images/yfdai-finance.png
# removing images/yasha-dao.png
# removing images/huobi-polkadot.png
# removing images/nusd.png
# removing images/wagmi.jpg
# removing images/cryptotask-2.png
# removing images/metamorph.png
# removing images/nucypher.jpg
# removing images/index-cooperative.png
# removing images/advanced-united-continent.png
# removing images/tokendesk.png
# removing images/meridian-network.png
# removing images/rally-2.png
# removing images/unicap-finance.png
# removing images/teaswap-art.png
# removing images/genesis-vision.png
# removing images/lever-network.png
# removing images/scalara-nft-index.png
# removing images/stafi.jpg
# removing images/kongtama.jpeg
# removing images/chainbing.png
# removing images/republic-protocol.png
# removing images/3x-long-sushi-token.png
# removing images/qanplatform.png
# removing images/moviebloc.png
# removing images/falcon-token.png
# removing images/dextf.jpg
# removing images/tornado-cash.jpg
# removing images/lilflokiceo.jpeg
# removing images/goldmint.png
# removing images/lepasa.png
# removing images/essentia.jpg
# removing images/yfdfi-finance.png
# removing images/cube.jpg
# removing images/xceltoken-plus.jpg
# removing images/exchange-union.png
# removing images/hollygold.jpg
# removing images/mintstarter.png
# removing images/insight-protocol.png
# removing images/tena.jpg
# removing images/millennium-sapphire.jpg
# removing images/lto-network.png
# removing images/banketh.png
# removing images/iot-chain.png
# removing images/ampnet.png
# removing images/bcv.jpg
# removing images/nkcl-classic.png
# removing images/sether.png
# removing images/childhoods-end.jpg
# removing images/hoo-token.jpeg
# removing images/bixcpro.jpg
# removing images/alien-worlds.jpg
# removing images/secret-finance.png
# removing images/depay.png
# removing images/dog-collar.png
# removing images/bitcoinlegend.jpg
# removing images/parastate.png
# removing images/punks-comic.png
# removing images/0-5x-long-theta-network-token.png
# removing images/futureswap.png
# removing images/anomus-coin.png
# removing images/kuramainu.png
# removing images/platform-for-underpaid-female-athletes.png
# removing images/winco.png
# removing images/xsushi.png
# removing images/game-stars.png
# removing images/amun-defi-index.png
# removing images/elynet-token.png
# removing images/homeros.jpg
# removing images/zenith-chain.png
# removing images/tosdis.png
# removing images/onbuff.jpg
# removing images/bigbom-eco.png
# removing images/masq.png
# removing images/bezant.png
# removing images/shopping-io.png
# removing images/social-rocket.png
# removing images/digible.png
# removing images/pax-gold.png
# removing images/smartmesh.png
# removing images/1x-short-tomochain-token.png
# removing images/mancium.jpg
# removing images/mt-pelerin-shares.png
# removing images/pathdao.png
# removing images/quinads.png
# removing images/bns-token-old.jpg
# removing images/decentralized-business-systems.png
# removing images/quidd.png
# removing images/zeptagram.png
# removing images/bobs_repair.png
# removing images/roge.png
# removing images/bestay.jpg
# removing images/lol.png
# removing images/tolar.png
# removing images/dao-invest.png
# removing images/goldenugget.png
# removing images/multiplier.png
# removing images/engine.png
# removing images/minds.png
# removing images/benddao.png
# removing images/klist-protocol.jpg
# removing images/blackmoon-crypto.png
# removing images/coreto.png
# removing images/q-dao-governance-token-v1-0.png
# removing images/skull.png
# removing images/neurotoken.png
# removing images/hyve.png
# removing images/frmx-token.png
# removing images/pension-plan.png
# removing images/bitcoin-red.png
# removing images/1x-short-vechain-token.png
# removing images/zusd.png
# removing images/lcx.jpg
# removing images/plug.jpg
# removing images/lgcy-network.jpg
# removing images/ucash.png
# removing images/bnsd-finance.png
# removing images/codyfight.png
# removing images/changex.png
# removing images/alita-network.jpg
# removing images/ether-1.png
# removing images/utrust.png
# removing images/temple.jpg
# removing images/bitcoin-pro.png
# removing images/chinu.png
# removing images/leisuremeta.jpg
# removing images/gamecredits.png
# removing images/incooom-genesis.png
# removing images/nosturis.jpg
# removing images/escoin-token.png
# removing images/civfund-stone.png
# removing images/pibble.jpg
# removing images/kimex.png
# removing images/babylon-finance.png
# removing images/yearn-finance-management.png
# removing images/insuredao.png
# removing images/monstaverse.png
# removing images/disbalancer.png
# removing images/digg.png
# removing images/opennity.jpg
# removing images/razor-network.png
# removing images/polkadomain.png
# removing images/vanilla.jpg
# removing images/durham-inu.jpg
# removing images/worldcore.png
# removing images/wrapped-statera.png
# removing images/dronefly.png
# removing images/zappay.png
# removing images/polysports.jpg
# removing images/definer.png
# removing images/limestone-network.png
# removing images/airswap.png
# removing images/immutable-x.png
# removing images/marsx.png
# removing images/reef.png
# removing images/lido-staked-matic.png
# removing images/reth2.png
# removing images/dos-network.png
# removing images/1x-short-matic-token.png
# removing images/delio-dsp.png
# removing images/uniwhales.png
# removing images/beekan.png
# removing images/blitzpredict.jpg
# removing images/content-value-network.png
# removing images/satt.png
# removing images/instadapp.jpg
# removing images/baby-saitama.png
# removing images/mammoth-mmt.png
# removing images/showhand.png
# removing images/pastel.jpg
# removing images/moonbirds-nft-index-by-mexc.jpg
# removing images/ethereum-volatility-index-token.png
# removing images/shibaverse.png
# removing images/frontier_logo-large.webp
# removing images/ceek.png
# removing images/eurocoinpay.png
# removing images/napoleon-x.jpg
# removing images/tether-gold.png
# removing images/bartertrade.png
# removing images/mex.png
# removing images/cult-dao.jpg
# removing images/amis.png
# removing images/unicly.png
# removing images/katana-inu.png
# removing images/defi-stoa.jpeg
# removing images/hord.png
# removing images/unium.png
# removing images/everipedia.png
# removing images/metasens.png
# removing images/lithium-finance.png
# removing images/mobiecoin.jpg
# removing images/union-protocol-governance-token.png
# removing images/herbalist-token.png
# removing images/makes.png
# removing images/xpad.jpg
# removing images/tether-eurt.png
# removing images/pixelverse.png
# removing images/yearn-ecosystem-token-index.png
# removing images/eden.jpg
# removing images/zeroswap.jpg
# removing images/coldbank.png
# removing images/kira-network.png
# removing images/cogecoin.png
# removing images/caave.png
# removing images/duo.png
# removing images/mcontent.jpeg
# removing images/hotdollars-token.jpg
# removing images/ideachain.jpg
# removing images/polkainsure-finance.png
# removing images/enreachdao.jpg
# removing images/touchcon.png
# removing images/hurify.jpg
# removing images/sator.png
# removing images/binance-wrapped-btc.png
# removing images/humans-ai.png
# removing images/bacon-coin.png
# removing images/castweet.png
# removing images/compound-usd-coin.png
# removing images/singularitydao.png
# removing images/azuki.png
# removing images/piedao-dough-v2.png
# removing images/bao-finance.png
# removing images/aura-finance.png
# removing images/etherisc.png
# removing images/deus-finance-2.png
# removing images/reserve-rights-token.png
# removing images/esports.jpg
# removing images/x2y2.png
# removing images/oilage.png
# removing images/charged-particles.png
# removing images/okb.png
# removing images/minter-network.jpg
# removing images/bitsonic-token.png
# removing images/safemoon-inu.png
# removing images/joinblocks.png
# removing images/gecoin.png
# removing images/mexican-peso-tether.jpg
# removing images/upper-swiss-franc.png
# removing images/genart.jpeg
# removing images/medican-coin.png
# removing images/morpheus-labs.png
# removing images/sidus.png
# removing images/public-mint.png
# removing images/ethereum-name-service.jpg
# removing images/curio-governance.png
# removing images/i-will-poop-it-nft.png
# removing images/uniqueone-photo.png
# removing images/stratos.png
# removing images/angryb.png
# removing images/bancor-governance-token.png
# removing images/kyber-network.png
# removing images/eco-value-coin.png
# removing images/idk.png
# removing images/elis.png
# removing images/first-inu.png
# removing images/global-digital-content.jpg
# removing images/innovativebioresearchclassic.png
# removing images/apeswap-finance.png
# removing images/destorage.png
# removing images/powerfan.png
# removing images/synchrolife.png
# removing images/rex.jpg
# removing images/metal.png
# removing images/dhealth.png
# removing images/metagaming-guild.png
# removing images/the-neko.jpg
# removing images/the-tokenized-bitcoin.png
# removing images/octopus-network.png
# removing images/dafi-protocol.png
# removing images/cratos.png
# removing images/confetti.png
# removing images/talken.jpg
# removing images/argo.png
# removing images/unimex-network.jpeg
# removing images/piccolo-inu.png
# removing images/innovaminex.jpg
# removing images/traxia.png
# removing images/interfinex-bills.png
# removing images/giveth.png
# removing images/happyfans.jpeg
# removing images/monerium-eur-money.png
# removing images/peth18c.png
# removing images/carbon-gems.png
# removing images/bitmart-token.png
# removing images/truefi.png
# removing images/barnbridge.jpg
# removing images/derivadao.png
# removing images/falcon-nine.png
# removing images/arc-governance.png
# removing images/fren.png
# removing images/hero-token.png
# removing images/1x-short-chainlink-token.png
# removing images/huobi-bitcoin-cash.png
# removing images/cream-eth2.png
# removing images/ethlend.png
# removing images/hokkaidu-inu.png
# removing images/hdpunk-vault-nftx.png
# removing images/build-finance.png
# removing images/kishu-inu.png
# removing images/young.png
# removing images/hzm-coin.png
# removing images/era-swap-token.png
# removing images/benzene.png
# removing images/grearn.jpg
# removing images/game.png
# removing images/gotham.png
# removing images/gala.png
# removing images/bengals.png
# removing images/matrexcoin.jpg
# removing images/gsenetwork.png
# removing images/cryptoprofile.png
# removing images/general-attention-currency.png
# removing images/media-network.png
# removing images/pulsedogecoin.png
# removing images/degenerator.jpeg
# removing images/btrips.png
# removing images/wrapped-zcash.png
# removing images/minato.png
# removing images/game-city.jpg
# removing images/true-pnl.png
# removing images/gamma-strategies.png
# removing images/chiliz.png
# removing images/clifford-inu.png
# removing images/curryswap.jpg
# removing images/blaze-network.jpg
# removing images/bytedex.jpg
# removing images/cool-monke-banana.png
# removing images/massive-protocol.png
# removing images/cocos-bcx.jpg
# removing images/coinghost.png
# removing images/hermez-network-token.png
# removing images/dusk-network.png
# removing images/xfit.png
# removing images/wepower.png
# removing images/lovechain.png
# removing images/artfinity-token.png
# removing images/markaccy.png
# removing images/electrum-dark.png
# removing images/polkafantasy.png
# removing images/polkaswap.png
# removing images/cardwallet.png
# removing images/balancer.png
# removing images/cointorox.png
# removing images/geodb.png
# removing images/patientory.png
# removing images/everus.png
# removing images/voxel-x-network.png
# removing images/apollo-crypto.png
# removing images/oxy-dev.jpeg
# removing images/volt.png
# removing images/tcash.jpg
# removing images/bean.png
# removing images/wilder-world.png
# removing images/danat-coin.png
# removing images/ferrum-network.png
# removing images/playfuel.jpg
# removing images/prism-network.png
# removing images/thx.jpg
# removing images/mongoose.png
# removing images/senate.png
# removing images/a-hunters-dream.jpg
# removing images/athens.png
# removing images/zero-exchange.jpg
# removing images/krypton-token.png
# removing images/roobee.png
# removing images/kstarcoin.png
# removing images/holyheld-2.jpg
# removing images/nodeseeds.png
# removing images/wizards-and-dragons.jpg
# removing images/butterflydao.png
# removing images/bluzelle.png
# removing images/aioz-network.png
# removing images/render-token.png
# removing images/lever.jpeg
# removing images/ondo-finance.jpg
# removing images/trias-token.jpg
# removing images/etherland.png
# removing images/nemesis.jpg
# removing images/defil.png
# removing images/elysia.jpg
# removing images/gro-vault-token.png
# removing images/tardigrades-finance.png
# removing images/lunchdao.png
# removing images/matrixetf.png
# removing images/exmo-coin.png
# removing images/got-guaranteed.png
# removing images/polkastarter.png
# removing images/fintab.png
# removing images/hackerlabs-dao.jpg
# removing images/tycoon.png
# removing images/smartofgiving.png
# removing images/bent-finance.png
# removing images/speed-mining-service.png
# removing images/bobcoin.png
# removing images/arch-ethereum-web3.png
# removing images/radioshack.jpg
# removing images/cindicator.png
# removing images/gimmer.jpg
# removing images/hellogold.png
# removing images/propy.png
# removing images/aidcoin.png
# removing images/seth2.png
# removing images/bread.png
# removing images/spaceswap-shake.png
# removing images/maker.png
# removing images/vader-protocol.jpg
# removing images/coinweb.png
# removing images/e-money.jpg
# removing images/dymmax.png
# removing images/kromatika.png
# removing images/hyper-trust.png
# removing images/skey-network.png
# removing images/aeron.png
# removing images/bribe.jpg
# removing images/bone-shibaswap.png
# removing images/binance-smart-chain-girl.png
# removing images/crafting-finance.png
# removing images/velas.png
# removing images/adventure-gold.jpg
# removing images/vera-exchange.jpg
# removing images/mcs-token.png
# removing images/vendit.png
# removing images/dirty-finance.png
# removing images/etor.jpg
# removing images/crypto-application-token.png
# removing images/ash.png
# removing images/dora-factory.jpg
# removing images/virtual-goods-token.png
# removing images/rigoblock.png
# removing images/coinspaid.png
# removing images/defiat.jpg
# removing images/inkz.png
# removing images/softchain.jpg
# removing images/coinsbit-token.png
# removing images/3x-short-defi-index-token.png
# removing images/dai.png
# removing images/plena.png
# removing images/apex-predator.jpg
# removing images/nrgy-defi.jpeg
# removing images/araw-token.png
# removing images/chonk.jpeg
# removing images/frax-share.png
# removing images/oh-finance.png
# removing images/wasder.png
# removing images/potentiam.png
# removing images/axus-coin.png
# removing images/otcbtc-token.jpg
# removing images/minter-hub.png
# removing images/blockv.png
# removing images/gyen.png
# removing images/loom-network.png
# removing images/zynecoin.png
# removing images/pocket-node.jpg
# removing images/polka-city.png
# removing images/connectome.png
# removing images/gold-mining-members.png
# removing images/onefuse.png
# removing images/unipilot.png
# removing images/basis-dollar-share.png
# removing images/pussy-financial.png
# removing images/flux-token.jpeg
# removing images/edge.png
# removing images/clover.png
# removing images/fortune.png
# removing images/1x-short-cardano-token.png
# removing images/bigbang-game.jpg
# removing images/token-play.png
# removing images/adelphoi.png
# removing images/cpucoin.png
# removing images/incognito-2.png
# removing images/webcoin.png
# removing images/cannabis-seed-token.png
# removing images/ethereum-lite.png
# removing images/assetmantle.png
# removing images/fintrux.png
# removing images/totemfi.png
# removing images/basketdao.png
# removing images/bitcoinsov.png
# removing images/kaizen.png
# removing images/humandao.jpg
# removing images/litecoin-sv.png
# removing images/dego-finance.png
# removing images/the-americans-nft.jpg
# removing images/cryptoenergy.jpg
# removing images/virtue-poker.png
# removing images/night-life-crypto.png
# removing images/cost-coin.png
# removing images/nvirworld.png
# removing images/legends-room.png
# removing images/tryc.png
# removing images/tessla-coin.png
# removing images/dawn-protocol.png
# removing images/tokencard.png
# removing images/atlas-usv.png
# removing images/ethernaal.png
# removing images/playchip.png
# removing images/moonrock-v2.png
# removing images/base-protocol.png
# removing images/unbanked.png
# removing images/truehkd.png
# removing images/julien.jpg
# removing images/main.png
# removing images/thx-network.png
# removing images/streamr-xdata.png
# removing images/multi-farm-capital.png
# removing images/fantom.png
# removing images/digixdao.png
# removing images/linkcoin-token.png
# removing images/dope-wars-paper.png
# removing images/charli3.png
# removing images/inmediate.jpg
# removing images/audius.png
# removing images/keisuke-inu.png
# removing images/mork.png
# removing images/pusd-2.png
# removing images/api3.jpg
# removing images/medishares.png
# removing images/3x-short-compound-token-token.png
# removing images/new-order.png
# removing images/wirex.jpg
# removing images/uma.png
# removing images/ubiner.png
# removing images/fnb-protocol.jpg
# removing images/parsiq.png
# removing images/uno-re.png
# removing images/blockchain-monster-hunt.png
# removing images/mooney.png
# removing images/totoro-inu.png
# removing images/intervalue.png
# removing images/cosplay-token.png
# removing images/kirobo.png
# removing images/perion.png
# removing images/tendies.jpg
# removing images/mars.png
# removing images/global-reserve-system.png
# removing images/apyswap.png
# removing images/blocknotex.png
# removing images/ssv-network.png
# removing images/newinu.png
# removing images/wpt-investing-corp.png
# removing images/stater.png
# removing images/tokenplace.png
# removing images/metabrands.png
# removing images/paralink-network.png
# removing images/keytango.jpg
# removing images/blocksquare.jpg
# removing images/constitutiondao.jpg
# removing images/hashmasks.jpg
# removing images/bully-inu.jpg
# removing images/mozik.png
# removing images/redfox-labs-2.png
# removing images/vega-protocol.png
# removing images/tsuki-inu.png
# removing images/natural-farm-union-protocol.png
# removing images/pinkslip-finance.png
# removing images/arteq-nft-investment-fund.png
# removing images/torex.png
# removing images/xsgd.png
# removing images/anrkey-x.jpg
# removing images/unisocks.png
# removing images/eautocoin.png
# removing images/qfora.png
# removing images/pikachu.png
# removing images/artcoin.png
# removing images/lattice-token.jpg
# removing images/xreators.png
# removing images/seur.png
# removing images/relay-token.png
# removing images/sapien.png
# removing images/ballswap.png
# removing images/gamercoin.png
# removing images/ethichub.png
# removing images/freeliquid.png
# removing images/ally.jpg
# removing images/swarm-city.png
# removing images/decentraweb.png
# removing images/edenloop.jpg
# removing images/jupiter.png
# removing images/coinmetro.png
# removing images/float-protocol-float.png
# removing images/piedao-yearn-ecosystem-pie.png
# removing images/saffron-finance.png
# removing images/baby-trump.png
# removing images/vodi-x.jpg
# removing images/lendingblock.png
# removing images/cryptyk.png
# removing images/unicly-doki-doki-collection.jpg
# removing images/thecash.png
# removing images/banana-task-force-ape.jpg
# removing images/crowd.png
# removing images/decentralized-nations.png
# removing images/amp-token.png
# removing images/monnos.png
# removing images/meta-doge.png
# removing images/airbloc-protocol.png
# removing images/dogeswap.png
# removing images/kineko.png
# removing images/salt.png
# removing images/alchemy-pay.png
# removing images/sandclock.jpg
# removing images/lixir-protocol.jpg
# removing images/ape-in.png
# removing images/brainiac.png
# removing images/liquity-usd.png
# removing images/carbon.png
# removing images/bondappetite-usd.png
# removing images/bt-finance.png
# removing images/parachute.png
# removing images/foam-protocol.png
# removing images/yfii-finance.png
# removing images/ara-token.png
# removing images/ethereum-gold-project.jpg
# removing images/hyperion.png
# removing images/choise.png
# removing images/impermax.png
# removing images/materium.png
# removing images/phillionex.jpg
# removing images/nft-protocol.png
# removing images/keeps-coin.png
# removing images/xdefi.png
# removing images/justcarbon-governance.png
# removing images/fanc.jpeg
# removing images/polkapet-world.png
# removing images/zip.png
# removing images/btu-protocol.jpeg
# removing images/hero-inu.png
# removing images/ccswap.png
# removing images/konpay.png
# removing images/hut34-entropy.png
# removing images/blockbank.jpg
# removing images/nunet.png
# removing images/biconomy.jpg
# removing images/coinnec.png
# removing images/matrixswap.png
# removing images/delphy.png
# removing images/decentralized-etf.jpg
# removing images/banksocial.png
# removing images/parsiq-boost.png
# removing images/ethereum-push-notification-service.jpg
# removing images/ape.png
# removing images/etherparty.png
# removing images/bosagora.png
# removing images/morpher.png
# removing images/isiklar-coin.png
# removing images/foho-coin.png
# removing images/neumark.png
# removing images/zoracles.png
# removing images/nexo.png
# removing images/delta-financial.png
# removing images/boringdao-btc.png
# removing images/primate.png
# removing images/labracoin.jpg
# removing images/global-human-trust.png
# removing images/utu-coin.png
# removing images/molecular-future.png
# removing images/niros.jpg
# removing images/lyfe-land.png
# removing images/adex.png
# removing images/britto.jpg
# removing images/ttc-protocol.png
# removing images/celestial.png
# removing images/dotoracle.png
# removing images/biotron.png
# removing images/jasmycoin.jpg
# removing images/alphadex.png
# removing images/verox.png
# removing images/aditus.png
# removing images/goldfarm.png
# removing images/inventoryclub.png
# removing images/velaspad.png
# removing images/wowswap.png
# removing images/elevate.png
# removing images/radar.png
# removing images/nftwiki.jpg
# removing images/froggies-token.png
# removing images/logitron.png
# removing images/peoples-punk.png
# removing images/digicol-token.png
# removing images/0-5x-long-bitcoin-token.png
# removing images/bitnorm.png
# removing images/fidex-exchange.jpg
# removing images/the-abyss.png
# removing images/daostack.png
# removing images/gamecrypt.png
# removing images/xcf-token.png
# removing images/maya-preferred-223.png
# removing images/boost.png
# removing images/0-5x-long-ethereum-token.png
# removing images/bluesparrow-token.png
# removing images/luna-inu.png
# removing images/mad-network.png
# removing images/funfair.png
# removing images/rigel-protocol.png
# removing images/divergence-protocol.jpg
# removing images/yearn-secure.png
# removing images/waxe.png
# removing images/e1337.png
# removing images/0-5x-long-privacy-index-token.png
# removing images/zeuxcoin.jpg
# removing images/elastos.png
# removing images/unicly-fewocious-collection.png
# removing images/blank.png
# removing images/unifi.png
# removing images/standard-protocol.jpeg
# removing images/crycash.png
# removing images/octofi.png
# removing images/unicly-mystic-axies-collection.png
# removing images/pudgy-vault-nftx.png
# removing images/decentralized-advertising.jpg
# removing images/usdp.png
# removing images/unicly-aavegotchi-astronauts-collection.jpg
# removing images/renbtc.jpg
# removing images/uhive.png
# removing images/bytz.png
# removing images/nebulas.png
# removing images/coshi-inu.jpg
# removing images/automata.jpg
# removing images/alphacoin.png
# removing images/kanpeki.png
# removing images/deapcoin.png
# removing images/iab.png
# removing images/dogeyield.png
# removing images/nsure-network.png
# removing images/aiwork.png
# removing images/mobilego.png
# removing images/dappatoz.jpeg
# removing images/axie-infinity.png
# removing images/fire-protocol.jpg
# removing images/huobi-pool-token.png
# removing images/weld.png
# removing images/apecoin.jpg
# removing images/aevolve-token.png
# removing images/oin-finance.png
# removing images/unvest.png
# removing images/origin-protocol.jpg
# removing images/inverse-ethereum-volatility-index-token.png
# removing images/parkgene.png
# removing images/force-for-fast.png
# removing images/mettalex.jpg
# removing images/hyperdao.png
# removing images/openswap.png
# removing images/cpchain.png
# removing images/e-chat.png
# removing images/noah-coin.png
# removing images/hybrix.png
# removing images/kok.png
# removing images/friesdao.png
# removing images/giftedhands.png
# removing images/swerve-dao.png
# removing images/friendz.png
# removing images/3x-short-maker-token.png
# removing images/metric-exchange.png
# removing images/trustswap.png
# removing images/datx.png
# removing images/hot-cross.png
# removing images/holotoken.png
# removing images/spheroid-universe.png
# removing images/bamboonium.png
# removing images/blockmason-credit-protocol.jpg
# removing images/cloutcontracts.png
# removing images/oxygen.jpg
# removing images/mimo-parallel-governance-token.png
# removing images/pandadao.png
# removing images/blocery.png
# removing images/latoken.png
# removing images/zelwin.png
# removing images/pstake-finance.png
# removing images/playgame.png
# removing images/gton-capital.png
# removing images/polyient-games-governance-token.png
# removing images/huobi-token.png
# removing images/zytara-dollar.png
# removing images/cigarette-token.png
# removing images/bishu-finance.jpeg
# removing images/marlin.png
# removing images/origin-dollar.png
# removing images/husd.jpg
# removing images/woozoo-music.png
# removing images/seen.png
# removing images/coti.png
# removing images/torocus-token.png
# removing images/ethdox.png
# removing images/givingtoservices-svs.png
# removing images/morpheus-network.png
# removing images/ethereummax.png
# removing images/gonetwork.png
# removing images/exmr-monero.png
# removing images/decentralized-machine-learning.png
# removing images/deficliq.png
# removing images/slink.png
# removing images/fomoeth.jpg
# removing images/gamee.png
# removing images/hubcoin-2.png
# removing images/boson-protocol.png
# removing images/idle.png
# removing images/kiki.jpg
# removing images/puppy-token.jpg
# removing images/meeb-vault-nftx.png
# removing images/polkamarkets.jpg
# removing images/eosdac.png
# removing images/ebox.png
# removing images/assemble-protocol.jpg
# removing images/maidsafecoin.png
# removing images/ftx-token.png
# removing images/own-token.jpeg
# removing images/noia-network.png
# removing images/3x-long-swipe-token.png
# removing images/cryptoworld-vip.jpg
# removing images/boba-network.png
# removing images/gencoin-capital.png
# removing images/quant-network.jpg
# removing images/time-new-bank.png
# removing images/matic-wormhole.png
# removing images/splyt.png
# removing images/ai-doctor.png
# removing images/serum.png
# removing images/dreamr-platform-token.png
# removing images/boosto.png
# removing images/unido-ep.jpg
# removing images/rac.jpg
# removing images/starbase.png
# removing images/wiki-token.jpg
# removing images/baby-doge-coin.png
# removing images/connect-coin.jpg
# removing images/hollaex-token.png
# removing images/lunachow.jpg
# removing images/redpanda-earth.jpg
# removing images/cranx-chain.png
# removing images/omniwhirl.png
# removing images/tr3zor.jpg
# removing images/iht-real-estate-protocol.png
# removing images/ureeqa.png
# removing images/energo.png
# removing images/hypersign-identity-token.png
# removing images/euler.jpeg
# removing images/alt-estate.jpg
# removing images/euro-coin.png
# removing images/vidiachange.png
# removing images/aegis.png
# removing images/curate.png
# removing images/aleph.png
# removing images/mixsome.png
# removing images/prostarter-token.png
# removing images/tacos.jpg
# removing images/avinoc.jpg
# removing images/dentacoin.png
# removing images/bitwell-token.jpg
# removing images/mithril-share.png
# removing images/forexcoin.png
# removing images/kanga-exchange.png
# removing images/the-4th-pillar.png
# removing images/londoncoingold.jpg
# removing images/the-doge-nft.png
# removing images/elvantis.png
# removing images/decentral-games-governance.png
# removing images/metafinance.png
# removing images/matic-network.png
# removing images/swissborg.png
# removing images/change.png
# removing images/green-flow.png
# removing images/metaoctagon.jpeg
# removing images/quadrant-protocol.png
# removing images/polymath.png
# removing images/bitcoin-one.png
# removing images/sacks.jpg
# removing images/blockchain-cuties-universe.jpg
# removing images/doki-doki-finance.png
# removing images/wrapped-dgld.png
# removing images/nft-platform-index.png
# removing images/rigel-finance.png
# removing images/jubi-token.jpg
# removing images/defire.png
# removing images/loon-network.jpg
# removing images/decentraland.png
# removing images/fluffy-inu.png
# removing images/bitto-exchange.jpg
# removing images/paint.png
# removing images/meta_finance.jpg
# removing images/lossless.png
# removing images/keep3rv1.jpg
# removing images/metashib-token.png
# removing images/darwinia-commitment-token.png
# removing images/3x-long-defi-index-token.png
# removing images/unifty.png
# removing images/crust-storage-market.png
# removing images/ibetyou.jpg
# removing images/gerowallet.jpg
# removing images/xy-finance.png
# removing images/xov.jpg
# removing images/oddz.png
# removing images/jpeg-d.jpg
# removing images/tenxcoin.png
# removing images/torg.png
# removing images/shapeshift-fox-token.png
# removing images/mcn-ventures.png
# removing images/swag-finance.jpeg
# removing images/wallfair.png
# removing images/rate3.png
# removing images/oiler.png
# removing images/devita-global.png
# removing images/pontoon.png
# removing images/incube-chain.jpg
# removing images/mossland.png
# removing images/dragonbit.png
# removing images/basis-bond.png
# removing images/hanu-yokia.png
# removing images/magic-inu.png
# removing images/jarvis-synthetic-euro.png
# removing images/tube2.png
# removing images/umi-digital.png
# removing images/matchpool.png
# removing images/tap.jpg
# removing images/mybit-token.png
# removing images/ultrain.png
# removing images/breezecoin.png
# removing images/pinknode.png
# removing images/american-shiba.png
# removing images/banana-token.jpg
# removing images/alethea-artificial-liquid-intelligence-token.png
# removing images/numeraire.png
# removing images/gric.png
# removing images/somee-social-old.png
# removing images/genomesdao.png
# removing images/chicken.png
# removing images/mgc-token.png
# removing images/wrapped-leo.png
# removing images/sota-finance.png
# removing images/dogus.png
# removing images/honey.png
# removing images/apenft.jpg
# removing images/beatbind.png
# removing images/typhoon-cash.jpg
# removing images/colony-network-token.png
# removing images/doge-zilla.png
# removing images/killswitch.png
# removing images/endor.png
# removing images/esg-chain.png
# removing images/dynamite-token.jpg
# removing images/dao1.png
# removing images/candle.png
# removing images/blue.jpg
# removing images/balancer-boosted-aave-dai.png
# removing images/cudos.png
# removing images/dxdao.png
# removing images/litentry.png
# removing images/crypto-accept.png
# removing images/crypto-excellence.jpg
# removing images/baddest-alpha-ape-bundle.jpg
# removing images/auction.jpeg
# removing images/arth.png
# removing images/daohaus.png
# removing images/ulanco.png
# removing images/netkoin.png
# removing images/degenvc.png
# removing images/sbtc.png
# removing images/polkaex.png
# removing images/b2u-coin.png
# removing images/wings.png
# removing images/openocean.png
# removing images/lotto.png
# removing images/lean-management-token.png
# removing images/triumphx.png
# removing images/kangal.png
# removing images/mintyswap.png
# removing images/tepleton.png
# removing images/try-finance.png
# removing images/kuende.png
# removing images/dust-token.png
# removing images/insureum.png
# removing images/amc-fight-night.png
# removing images/skrumble-network.png
# removing images/celsiusx-wrapped-btc.png
# removing images/dfx-finance.png
# removing images/metria.png
# removing images/mytoken.png
# removing images/sovryn.png
# removing images/usdd.jpg
# removing images/izumi-finance.png
# removing images/smartshare.png
# removing images/forefront.jpg
# removing images/cash-tech.jpg
# removing images/imperial-obelisk.png
# removing images/rss3.png
# removing images/magick-dao.png
# removing images/cryptonits.png
# removing images/easyfi.png
# removing images/qchi.png
# removing images/tigerqueen.png
# removing images/tonestra.jpg
# removing images/flex-usd.png
# removing images/trillion.jpg
# removing images/genesis-token.jpg
# removing images/tokenlon.png
# removing images/yff-finance.jpg
# removing images/bitcci-cash.png
# removing images/tourist-token.png
# removing images/obortech.png
# removing images/spool-dao-token.png
# removing images/fx-coin.jpg
# removing images/alpha-pad.png
# removing images/gods-unchained.png
# removing images/zeusshield.png
# removing images/ethermon.jpg
# removing images/everex.png
# removing images/decurian.png
# removing images/nobunaga.jpeg
# removing images/myobu.png
# removing images/camp.png
# removing images/ankr-matic-reward-earning-bond.png
# removing images/basis-cash.png
# removing images/libra-credit.png
# removing images/tratok.png
# removing images/arcadetoken.png
# removing images/bitceo.jpg
# removing images/zedxion.png
# removing images/scifi-index.png
# removing images/bintex-futures.png
# removing images/viberate.png
# removing images/hummingbot.jpg
# removing images/blockify-games.png
# removing images/vesper-finance.jpg
# removing images/boom-token.png
# removing images/micromoney.png
# removing images/chadfi.png
# removing images/yfx.png
# removing images/vabble.png
# removing images/polkarare.png
# removing images/btecoin.jpg
# removing images/distx.png
# removing images/finance-vote.png
# removing images/mysterium.png
# removing images/mcdoge.png
# removing images/betherchip.jpg
# removing images/fiftyonefifty.png
# removing images/mogul-productions.png
# removing images/polkabridge.png
# removing images/sarcophagus.jpeg
# removing images/bethereum.png
# removing images/frax-price-index.png
# removing images/aircoins.png
# removing images/gro-dao-token.png
# removing images/fuzex.png
# removing images/zyx.png
# removing images/flex-coin.png
# removing images/zenfuse.jpg
# removing images/superbid.png
# removing images/meta-farmer-finance.jpg
# removing images/0-5x-long-chainlink-token.png
# removing images/defipulse-index.png
# removing images/alpha-finance.png
# removing images/busy-dao.png
# removing images/aura-bal.png
# removing images/bloxmove-erc20.png
# removing images/sekuritance.png
# removing images/axis-defi.jpg
# removing images/benchmark-protocol.jpg
# removing images/peacockcoin-eth.jpg
# removing images/alliance-cargo-direct.png
# removing images/insurace.png
# removing images/bulldog-token.png
# removing images/filecoin-standard-full-hashrate.jpg
# removing images/predix-network.png
# removing images/cargox.png
# removing images/unique-one.png
# removing images/bistroo.png
# removing images/onx-finance.png
# removing images/max-token.jpg
# removing images/bountymarketcap.png
# removing images/label-foundation.png
# removing images/dafin.png
# removing images/santiment-network-token.png
# removing images/model-x-coin.png
# removing images/infinitygaming.png
# removing images/king-arthur.png
# removing images/kpop-coin.png
# removing images/gravitationally-bound-aura.png
# removing images/sideshift-token.png
# removing images/wabi.png
# removing images/lokr.png
# removing images/yam-v2.png
# removing images/fsn.png
# removing images/bitlocus.png
# removing images/devour.png
# removing images/creditcoin-2.png
# removing images/ichi-farm.jpg
# removing images/when-token.png
# removing images/sync-network.png
# removing images/hash-token.png
# removing images/faithcoin.png
# removing images/monfter.png
# removing images/ethereum.png
# removing images/bns-token.png
# removing images/chainswap.png
# removing images/pivot-token.png
# removing images/bundles.jpg
# removing images/videocoin.jpg
# removing images/sentinel-chain.jpg
# removing images/prcy-coin.png
# removing images/all-coins-yield-capital.png
# removing images/engine-token.png
# removing images/crowns.png
# removing images/citadao.png
# removing images/day-by-day.png
# removing images/gatechain-token.png
# removing images/metabet.jpeg
# removing images/nanobyte.png
# removing images/paraswap.jpg
# removing images/ptokens-btc.png
# removing images/sensitrust.png
# removing images/nftrade.png
# removing images/defipie.png
# removing images/pawtocol.jpg
# removing images/h2o.png
# removing images/zeedex.png
# removing images/blocktanium.png
# removing images/babyfloki.jpg
# removing images/extradna.png
# removing images/ezystayz.png
# removing images/ruff.png
# removing images/thorswap.png
# removing images/yeticoin.png
# removing images/winter.png
# removing images/kush-finance.png
# removing images/nifty-league.png
# removing images/invi-token.png
# removing images/governor-dao.png
# removing images/dust.png
# removing images/varen.png
# removing images/astrotools.png
# removing images/coinage-finance.png
# removing images/paladin-stkaave.jpg
# removing images/follow-token.png
# removing images/vnx-exchange.png
# removing images/yearn-finance-dot.png
# removing images/ice-token.png
# removing images/banana-finance.png
# removing images/evrynet.png
# removing images/cool-cats.png
# removing images/dopex-rebate-token.png
# removing images/garlicoin.png
# removing images/carvertical.png
# removing images/gem-exchange-and-trading.png
# removing images/defactor.png
# removing images/dogetama.png
# removing images/polygen.jpeg
# removing images/wiva.png
# removing images/xaurum.png
# removing images/node-squared.png
# removing images/relite-finance.jpg
# removing images/melalie.jpeg
# removing images/archer-dao-governance-token.png
# removing images/artm.png
# removing images/prediqt.png
# removing images/avalanche-wormhole.png
# removing images/spaceswap-milk2.png
# removing images/hi-dollar.png
# removing images/bitsten-token.png
# removing images/yeni-malatyaspor-token.png
# removing images/foresight.jpg
# removing images/invictus-capital-token.png
# removing images/cybertronchain.png
# removing images/tracer-dao.png
# removing images/blue-baikal.png
# removing images/picipo.jpg
# removing images/arcs.png
# removing images/tripio.jpg
# removing images/ztcoin.jpg
# removing images/cryption-network.png
# removing images/mononoke-inu.png
# removing images/olympus.png
# removing images/nftx.jpg
# removing images/babydoge-coin-eth.png
# removing images/portion.png
# removing images/cleardao.png
# removing images/metis.jpg
# removing images/grapefruit-coin.png
# removing images/bollycoin.jpg
# removing images/smart-valor.png
# removing images/evencoin.png
# removing images/tigercash.png
# removing images/trueflip.png
# removing images/hundred-finance.png
# removing images/krause.png
# removing images/aelf.png
# removing images/stima.png
# removing images/fantasy-world-gold.png
# removing images/defi-on-mcw.png
# removing images/lightcoin.png
# removing images/mean-tamato.png
# removing images/bitboost.jpg
# removing images/synapse-2.png
# removing images/bifrost.png
# removing images/metadium.png
# removing images/fm-gallery.jpg
# removing images/nfx-coin.png
# removing images/qiibee.png
# removing images/darussafaka-sports-club.png
# removing images/italian-lira.png
# removing images/deku-inu.png
# removing images/foundrydao-logistics.png
# removing images/venjocoin.jpg
# removing images/fantomgo.jpg
# removing images/suretly.png
# removing images/unibright.png
# removing images/ape_in_records.jpeg
# removing images/eub-chain.jpg
# removing images/ccore.png
# removing images/dexpools.png
# removing images/floki-pup.png
# removing images/zippie.jpg
# removing images/vortex-defi.png
# removing images/whiteheart.png
# removing images/harrison-first.png
# removing images/cryptomoonshots.png
# removing images/neeva-defi.png
# removing images/orbs.jpg
# removing images/cudl-finance.png
# removing images/nitro-league.jpg
# removing images/cosmostarter.png
# removing images/gaj.png
# removing images/pollchain.png
# removing images/worldpet.png
# removing images/hiveterminal.jpg
# removing images/somee-advertising-token.png
# removing images/have-fun-staying-poor.png
# removing images/pulse-token.jpg
# removing images/transient.png
# removing images/marshall-rogan-inu.png
# removing images/snovio.png
# removing images/blox.png
# removing images/ethereum-meta.png
# removing images/vitadao.png
# removing images/loomi.jpg
# removing images/revomon.jpeg
# removing images/b-watch-box.png
# removing images/nfty-token.png
# removing images/yam-2.png
# removing images/xerium.png
# removing images/handle-fi.png
# removing images/dirham.png
# removing images/exnetwork-token.png
# removing images/meta.png
# removing images/sparkpoint.png
# removing images/skale.png
# removing images/feg-token.png
# removing images/tecracoin.jpg
# removing images/kryptopets.jpg
# removing images/mmaon.png
# removing images/showcase-token.png
# removing images/srcoin.png
# removing images/chi-gastoken.png
# removing images/kyber-network-crystal.jpg
# removing images/ubex.png
# removing images/yfbeta.jpg
# removing images/cache-gold.png
# removing images/face.png
# removing images/amo.png
# removing images/mxc.png
# removing images/coinpoker.jpg
# removing images/astroelon.png
# removing images/kittenfinance.png
# removing images/cryn.png
# removing images/hatayspor-token.png
# removing images/bitball-treasure.png
# removing images/armor.png
# removing images/energy-ledger.png
# removing images/en-tan-mo.jpg
# removing images/bulleon.jpg
# removing images/gourmetgalaxy.png
# removing images/jumptoken.png
# ...
# removing images/minereum.png
# removing images/botto.jpg
# removing images/aidi-inu.png
# removing images/work-quest.png
# removing images/tokenomy.png
# removing images/seigniorage-shares.png
# removing images/compound-chainlink-token.png
# removing images/stox.png
# removing images/ledgerscore.jpg
# removing images/vaiot.png
# removing images/alpaca.png
# removing images/zipmex-token.png
# removing images/winstars.jpg
# removing images/meebitsdao-pool.jpg
# removing images/idexo-token.jpg
# removing images/nil-coin.png
# removing images/gamestarter.jpg
# removing images/dodreamchain.jpg
# removing images/bithash-token.png
# removing images/prometeus.png
# removing images/terrausd-wormhole.png
# removing images/vent-finance.png
# removing images/pony-index.png
# removing images/etg-finance.png
# removing images/apm-coin.png
# removing images/matryx.png
# removing images/invest-like-stakeborg-index.png
# removing images/anchor-protocol.jpg
# removing images/nfcore.png
# removing images/infinity-pad.jpg
# removing images/netvrk.png
# removing images/ifx24.png
# removing images/zoodao.jpg
# removing images/fancy-games.png
# removing images/publish.png
# removing images/amdg-token.png
# removing images/pillar.png
# removing images/polinate.png
# removing images/dextoken-governance.png
# removing images/beyond-protocol.png
# removing images/bit2me.png
# removing images/meteorite-network.png
# removing images/poken.jpg
# removing images/mishka.png
# removing images/hopr.png
# removing images/dehive.png
# removing images/3x-long-maker-token.png
# removing images/harambe.jpg
# removing images/trustverse.png
# removing images/bobo-cash.png
# removing images/loot.png
# removing images/nftmall.png
# removing images/alchemix.png
# removing images/ceji.png
# removing images/cybermusic.png
# removing images/xfinance.png
# removing images/chex-token.png
# removing images/messier.png
# removing images/mars4.jpg
# removing images/themis-2.png
# removing images/element-black.jpg
# removing images/method-fi.png
# removing images/power-ledger.png
# removing images/universal-coin.png
# removing images/puriever.png
# removing images/xi-token.png
# removing images/baanx.png
# removing images/doont-buy.png
# removing images/upfiring.png
# removing images/infinity-esaham.png
# removing images/measurable-data-token.png
# removing images/akihiko-inu.jpeg
# removing images/gemini-dollar.png
# removing images/peri-finance.png
# removing images/somnium-space-cubes.png
# removing images/saddle-finance.png
# removing images/unlend-finance.png
# removing images/izanagi.jpg
# removing images/peerex-network.jpg
# removing images/magic.png
# removing images/sw-dao.png
# removing images/inlock-token.jpg
# removing images/golem.png
# removing images/vynk-chain.png
# removing images/marshal-lion-group-coin.jpg
# removing images/nextexchange.png
# removing images/ot-compound-dai.png
# removing images/metalk.png
# removing images/18276-appoline.png
# removing images/lung-protocol.png
# removing images/wrapped-virgin-gen-0-cryptokitties.png
# removing images/aggregatedfinance-2.png
# removing images/bmax.png
# removing images/hyperquant.png
# removing images/blackdragon-token.png
# removing images/couponbay.png
# removing images/dprating.png
# removing images/cross-chain-bridge.png
# removing images/monox.png
# removing images/gene.png
# removing images/nil-dao.jpg
# removing images/dfund.png
# removing images/blackpool-token.jpg
# removing images/verify.png
# removing images/crypto-holding-frank-token.png
# removing images/the-winkyverse.png
# removing images/gelato.png
# removing images/plasma-finance.png
# removing images/couchain.png
# removing images/coin.png
# removing images/hunt-token.png
# removing images/lockchain.png
# removing images/locus-chain.jpg
# removing images/0-5x-long-altcoin-index-token.png
# removing images/metagamehub-dao.png
# removing images/insula.png
# removing images/tribeone.png
# removing images/fiat-dao-token.jpg
# removing images/lyra-finance.png
# removing images/bazaars.png
# removing images/chromaway.png
# removing images/apix.png
# removing images/uchain.jpg
# removing images/avaocado-dao.png
# removing images/p2p.png
# removing images/tcoin-fun.png
# removing images/vikkytoken.png
# removing images/the-randomdao.png
# removing images/cryptochrome.png
# removing images/paratoken-2.png
# removing images/fyooz.png
# removing images/mask-vault-nftx.png
# removing images/lina.png
# removing images/crossfi.png
# removing images/sentivate.png
# removing images/k21.png
# removing images/luxtto.png
# removing images/united-traders-token.png
# removing images/bithachi.png
# removing images/ig-gold.png
# removing images/rmrk.png
# removing images/ethereum-cash-token.png
# removing images/volatility-protocol-token.png
# removing images/tenet.png
# removing images/fess-chain.jpg
# removing images/moeda-loyalty-points.png
# removing images/antedao.png
# removing images/baby-shiba-coin.jpg
# removing images/every-original.png
# removing images/dragonchain.png
# removing images/verisafe.png
# removing images/compound-sushi.png
# removing images/intelligent-monsters.png
# removing images/bidipass.jpg
# removing images/elamachain.png
# removing images/candela-coin.png
# removing images/threeoh-dao.jpeg
# removing images/heal-the-world.jpg
# removing images/moontools.png
# removing images/fox-trading-token.png
# removing images/chads-vc.png
# removing images/paribus.png
# removing images/suku.png
# removing images/pundi-x.png
# removing images/sergs.png
# removing images/jigstack.png
# removing images/tidal-finance.png
# removing images/lhcoin.jpg
# removing images/muse-2.png
# removing images/the-crypto-prophecies.png
# removing images/crossswap.png
# removing images/town-star.png
# removing images/crypto-perx.jpg
# removing images/spankchain.png
# removing images/yrise-finance.png
# removing images/cat-token.jpg
# removing images/connect-financial.png
# removing images/waltonchain.png
# removing images/mask-network.jpg
# removing images/strips-finance.png
# removing images/defiato.png
# removing images/plotx.png
# removing images/blockchain-quotations-index-token.png
# removing images/unicly-chris-mccann-collection.png
# removing images/kollector.jpg
# removing images/basid-coin.png
# removing images/voucher-eth.png
# removing images/botxcoin.jpg
# removing images/biopassport.png
# removing images/bitspawn.png
# removing images/pnetwork.png
# removing images/based-money.png
# removing images/core.png
# removing images/idle-dai-risk-adjusted.png
# removing images/platoncoin.png
# removing images/shiba-predator.png
# removing images/algory.png
# removing images/bgogo.png
# removing images/biokkoin.png
# removing images/lympo.png
# removing images/adventure-token.jpg
# removing images/opyn-squeeth.jpg
# removing images/guzzler.png
# removing images/blocksport.jpg
# removing images/puglife.png
# removing images/bitcoffeen.png
# removing images/uquid-coin.png
# removing images/thorstarter.jpg
# removing images/fidu.png
# removing images/donut.png
# removing images/dukascoin.png
# removing images/govi.png
# removing images/cultiplan.png
# removing images/advertise-coin.png
# removing images/royale.png
# removing images/flux-protocol.png
# removing images/esg.png
# removing images/crownsterling.jpg
# removing images/flux.png
# removing images/tsuzuki-inu.png
# removing images/pop-chest-token.png
# removing images/xpop.png
# removing images/depo.png
# removing images/digitalbits.jpg
# removing images/resfinex-token.png
# removing images/nfraction.png
# removing images/yokcoin.png
# removing images/cartesi.png
# removing images/ludos.jpg
# removing images/stone-token.png
# removing images/3x-short-swipe-token.png
# removing images/crybet.jpg
# removing images/robotina.png
# removing images/javascript-token.png
# removing images/grom.png
# removing images/gaindao.png
# removing images/phoenix-token.png
# removing images/rentible.png
# removing images/swirge.png
# removing images/umbrellacoin.jpg
# removing images/yearn-finance-passive-income.png
# removing images/0-5x-long-eos-token.png
# removing images/onooks.png
# removing images/cerealia.png
# removing images/boltt-coin.jpeg
# removing images/bamboo-defi.png
# removing images/tontoken.jpg
# removing images/polybius.png
# removing images/inescoin.png
# removing images/probably-nothing.png
# removing images/entropyfi.png
# removing images/paypolitan-token.png
# removing images/aurora-near.jpeg
# removing images/pdx-coin.jpg
# removing images/xels.png
# removing images/keep-network.jpg
# removing images/usd-coin-pos-wormhole.png
# removing images/duck-vault-nftx.png
# removing images/gifto.png
# removing images/yield-app.png
# removing images/captain-inu.png
# removing images/yearn-cash.png
# removing images/exentoken.png
# removing images/polytrade.png
# removing images/mochi-market.png
# removing images/basic.jpg
# removing images/marketpeak.png
# removing images/xio.jpg
# removing images/nestree.png
# removing images/ystar.png
# removing images/arti-project.png
# removing images/cherry-network.png
# removing images/concertvr.png
# removing images/libertas-token.png
# removing images/merchdao.png
# removing images/elk-finance.png
# removing images/universal-protocol-token.jpg
# removing images/webpay.jpg
# removing images/noblesscoin.jpg
# removing images/reflect-finance.png
# removing images/compound-ether.jpg
# removing images/parts-of-four-coin.png
# removing images/payaccept.png
# removing images/name-changing-token.png
# removing images/dforce-token.jpg
# removing images/hoqu.png
# removing images/district0x.png
# removing images/gather.png
# removing images/siren.png
# removing images/wrapped-ecomi.jpg
# removing images/folder-protocol.png
# removing images/ares-protocol.png
# removing images/cheqd-network.png
# removing images/formation-fi.png
# removing images/cbdao.jpg
# removing images/bright-union.png
# removing images/mirocana.jpg
# removing images/unlimitedip.png
# removing images/envoy-defi.png
# removing images/huh.png
# removing images/sav3.png
# removing images/unikoin-gold.png
# removing images/ucrowdme.png
# removing images/maidcoin.png
# removing images/evny-token.jpg
# removing images/flash-token.png
# removing images/bigshortbets.png
# removing images/pist-trust.png
# removing images/overline-emblem.png
# removing images/hapi.jpg
# removing images/kiba-inu.png
# removing images/define.png
# removing images/daoventures.png
# removing images/tokenize-xchange.png
# removing images/x-block.jpg
# removing images/mycro-ico.png
# removing images/ifarm.png
# removing images/dream-swap.png
# removing images/rainbow-token.png
# removing images/honey-fancybearsmetaverse.png
# removing images/juicebox.jpg
# removing images/pitch.jpg
# removing images/vibe.png
# removing images/ethereum-apex.png
# removing images/viiida-gold.png
# removing images/vndc.png
# removing images/zano.png
# removing images/compound-yearn-finance.png
# removing images/pixiu-finance.png
# removing images/volt-inu-2.png
# removing images/btc-2x-flexible-leverage-index.png
# removing images/token-pocket.jpg
# removing images/bankless-bed-index.png
# removing images/toshi-token.png
# removing images/sperax.jpg
# removing images/powertrade-fuel.jpg
# removing images/heartnumber.png
# removing images/film-coin.png
# removing images/nyx-token.png
# removing images/uwu-vault-nftx.png
# removing images/liquidswap.jpg
# removing images/idle-usdc-risk-adjusted.png
# removing images/agpc.jpg
# removing images/quai-dao.png
# removing images/revest-finance.png
# removing images/rare.png
# removing images/enterbutton.png
# removing images/solomon-defi.png
# removing images/xfund.png
# removing images/basketdao-defi-index.png
# removing images/leo-token.png
# removing images/piedao-balanced-crypto-pie.png
# removing images/unicly-mooncats-collection.jpg
# removing images/celcoin.png
# removing images/yield-protocol.png
# removing images/payyoda.png
# removing images/reserve.png
# removing images/mib-coin.png
# removing images/kondux.jpeg
# removing images/covalent.png
# removing images/opacity.jpg
# removing images/mandox-2.png
# removing images/nym.png
# removing images/dark-energy-crystals.png
# removing images/get-token.png
# removing images/corra-finance.png
# removing images/dexkit.png
# removing images/filipcoin.png
# removing images/every-game.png
# removing images/compound-basic-attention-token.jpg
# removing images/bnktothefuture.png
# removing images/convex-crv.png
# removing images/naruto-inu.jpeg
# removing images/ojamu.png
# removing images/munch-token.png
# removing images/gnosis.png
# removing images/definity.png
# removing images/alphatoken.png
# removing images/concave.jpg
# removing images/onigiri.png
# removing images/fortknoxter.png
# removing images/xtoken.png
# removing images/boringdao-[old].png
# removing images/stronger.png
# removing images/ethorse.png
# removing images/bitgear.png
# removing images/polka-ventures.png
# removing images/piedao-btc.png
# removing images/tenx.png
# removing images/red.png
# removing images/yel-finance.png
# removing images/fei-usd.png
# removing images/openleverage.png
# removing images/ecoscu.png
# removing images/echolink.png
# removing images/orbler.jpg
# removing images/zebi.png
# removing images/erugo-world-coin.jpg
# removing images/uplift.png
# removing images/gitcoin.png
# removing images/linka.jpg
# removing images/blockcdn.png
# removing images/greeneum-network.png
# removing images/giga-watt-token.png
# removing images/stepn.png
# removing images/digifinextoken.png
# removing images/evident-proof-transaction-token.png
# removing images/volt-inu.png
# removing images/umi.png
# removing images/mogu.jpg
# removing images/fera.jpg
# removing images/united-emirate.jpg
# removing images/seth.png
# removing images/block-18.jpg
# removing images/presearch.png
# removing images/decentbet.jpg
# removing images/spice-finance.png
# removing images/universe-xyz.png
# removing images/relevant.png
# removing images/rotten.png
# removing images/charizard-inu.png
# removing images/chronobank.png
# removing images/localcoinswap.png
# removing images/freedom-22-dao.jpg
# removing images/zeon.jpg
# removing images/pha.png
# removing images/whole-earth-coin.png
# removing images/rendoge.jpg
# removing images/1x-short-cosmos-token.png
# removing images/qredo.png
# removing images/wagmi-game-2.jpg
# removing images/ziot.png
# removing images/metronome.png
# removing images/yearn-finance-infrastructure-labs.jpg
# removing images/blockchainpoland.png
# removing images/spiceusd.png
# removing images/vidya.png
# removing images/fanstime.png
# removing images/babelfish.png
# removing images/robonomics-network.png
# removing images/nft-stars.png
# removing images/world-token.png
# removing images/ispolink.png
# removing images/xbullion_silver.png
# removing images/herocoin.png
# removing images/instadapp-usdc.png
# removing images/cc.png
# removing images/membrana-platform.png
# removing images/jobchain.png
# removing images/human-protocol.png
# removing images/storm.png
# removing images/pledgecamp.png
# removing images/universal-gold.png
# removing images/cofix.png
# removing images/metis-token.png
# removing images/vegannation-greencoin.png
# removing images/piedao-defi.png
# removing images/fisco.png
# removing images/iqeon.png
# removing images/music-infinity-token.png
# removing images/creator-platform.png
# removing images/unity-network.png
# removing images/unfederalreserve.png
# removing images/flurry.png
# removing images/dav.jpg
# removing images/entercoin.png
# removing images/sonm.png
# removing images/bepro-network.png
# removing images/aga-token.png
# removing images/eth-note.png
# removing images/givly-coin.png
# removing images/ethereum-gold.png
# removing images/throne.jpg
# removing images/cruize-finance.png
# removing images/zin.png
# removing images/kelvpn.png
# removing images/tozex.png
# removing images/polylauncher.png
# removing images/terran-coin.png
# removing images/dfohub.png
# removing images/artem.png
# removing images/poundtoken.jpeg
# removing images/staked-ether.png
# removing images/infinite-arcade-tic.jpg
# removing images/dhedge-dao.png
# removing images/tia.png
# removing images/latiumx.jpg
# removing images/linkpool.png
# removing images/coinversation.png
# removing images/rio-defi.png
# removing images/dxsale-network.png
# removing images/apple-protocol-token.png
# removing images/ethpad.jpg
# removing images/buckhath-coin.png
# removing images/props.png
# removing images/gems-2.jpg
# removing images/box-token.png
# removing images/wolfy.png
# removing images/bankless-defi-innovation-index.png
# removing images/yfox-finance.png
# removing images/mobilian-coin.jpg
# removing images/kaiba-defi.png
# /Users/blockexplorer/Library/Python/3.9/lib/python/site-packages/PIL/TiffImagePlugin.py:845: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))

# %%
# Get color images
from PIL import ImageColor
